# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_parquet('midterm.parquet', engine='pyarrow')
data
# Out:
#                    Artist                                        Spotify_URL  \
# 0                Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1             Beach House  https://open.spotify.com/artist/56ZTgzPBDge0Ov...
# 2                Al Green  https://open.spotify.com/artist/3dkbV4qihUeMsq...
# 3                Al Green  https://open.spotify.com/artist/3dkbV4qihUeMsq...
# 4             Beach House  https://open.spotify.com/artist/56ZTgzPBDge0Ov...
# ...                   ...                                                ...
# 20713   Michael Giacchino  https://open.spotify.com/artist/4kLvhMAuCloLxo...
# 20714                 ATB  https://open.spotify.com/artist/7jZM5w05mGhw6w...
# 20715            Blueface  https://open.spotify.com/artist/3Fl1V19tmjt57o...
# 20716  Tribo da Periferia  https://open.spotify.com/artist/1xxS2WrLlgl9QN...
# 20717            Hardwell  https://open.spotify.com/artist/6BrvowZBreEkXz...
#
# ...

# %% [markdown]
# პირველ რიგში წამოვიღებთ დატის ქოლამნებს რომ გავიგოთ რასთან მოგვიწევს მუშაობა, აგრეთვე გავიგებთ რა შეიფი აქვს ჩვენს ფაილს.

# %%
data.shape
data.columns
# Out:
# Index(['Artist', 'Spotify_URL', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Youtube_URL', 'Youtube_Title', 'Youtube_Channel',
#        'Youtube_Views', 'Youtube_Likes', 'Youtube_number_of_Comments',
#        'Youtube_Description', 'Is_Licensed_on_Youtube', 'Is_official_video',
#        'Spotify_stream_num'],
#       dtype='object')

# %% [markdown]
# ვარკვევთ არის თუ არა ნალები მონაცემებში და დადებითი პასუხის შემთხვევაში სად და რამდენი

# %%
data.info()
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Artist                      20718 non-null  object
#  1   Spotify_URL                 20718 non-null  object
#  2   Track                       20718 non-null  object
#  3   Album                       20718 non-null  object
#  4   Album_type                  20718 non-null  object
#  5   Uri                         20718 non-null  object
#  6   Danceability                20718 non-null  object
#  7   Energy                      20716 non-null  float64
#  8   Key                         20716 non-null  float64
#  9   Loudness                    20716 non-null  float64
#  10  Speechiness                 20716 non-null  float64
#  11  Acousticness                20716 non-null  float64
#  12  Instrumentalness            20716 non-null  float64
# ...

# %% [markdown]
# შეძლებისდაგვარად ვასუფთავებთ მონაცემებს

# %%
data.dtypes
# Out:
# Artist                         object
# Spotify_URL                    object
# Track                          object
# Album                          object
# Album_type                     object
# Uri                            object
# Danceability                   object
# Energy                        float64
# Key                           float64
# Loudness                      float64
# Speechiness                   float64
# Acousticness                  float64
# Instrumentalness              float64
# Liveness                      float64
# Valence                       float64
# Tempo                         float64
# Duration_ms                   float64
# Youtube_URL                    object
# Youtube_Title                  object
# Youtube_Channel                object
# Youtube_Views                 float64
# Youtube_Likes                  object
# Youtube_number_of_Comments    float64
# Youtube_Description            object
# Is_Licensed_on_Youtube         object
# ...

# %%
data["Youtube_Likes"].mean()

# %% [markdown]
# Youtube_Likes - ის მონაცემებში გვაქვს არასტანდარტული ჩანაწერები, რომლებსაც ჩავანაცვლებთ ქოლამნის საშუალო მაჩვენებლით

# %%
a = data['Youtube_Likes'].unique()
print(sorted(a))
# Out:
# ['0.0', '1.0', '10.0', '100.0', '100026.0', '10003280.0', '10003295.0', '100086.0', '10009.0', '1000918.0', '100119.0', '100120.0', '100135.0', '100151.0', '100165.0', '100171.0', '100177.0', '100178.0', '1002.0', '1002083.0', '100235.0', '10024.0', '100255.0', '100269.0', '1002764.0', '10029.0', '100299.0', '1003351.0', '1003639.0', '1003865.0', '100388.0', '1004.0', '100401.0', '1004013.0', '100406.0', '1004203.0', '1004220.0', '1004221.0', '100432.0', '1004351.0', '100454.0', '100457.0', '1004611.0', '10048.0', '100484.0', '10049.0', '1004977.0', '1005.0', '100504.0', '100508.0', '1005116.0', '10052.0', '100526.0', '10053.0', '1005368.0', '10057.0', '1005808.0', '1006231.0', '100630.0', '1006580.0', '100672.0', '100674.0', '100693.0', '100734.0', '1007482.0', '100762.0', '1008.0', '1008010.0', '100805.0', '100807.0', '100820.0', '100830.0', '100835.0', '100856.0', '10086.0', '1008777.0', '100897.0', '100900.0', '1009011.0', '10093.0', '100937.0', '100941.0', '10095.0', '10096.0', 
# ...

# %%
data['Youtube_Likes'] = data['Youtube_Likes'].str.replace('(\D+)', '')
# data['Youtube_Likes'] = data['Youtube_Likes'].map(lambda i: ''.join([x for x in i if x.isdigit()]))

# %%
col = ['Youtube_Likes']
mask = data[col].applymap(lambda x: isinstance(x, (int, float)))

data[col] = data[col].where(mask)
print (data["Youtube_Likes"])

# %%
data["dup_bool"] = data.duplicated("Uri")
duplicates = data.loc[data["dup_bool"] == True]
duplicates.sort_values(by = 'Uri', ascending = True)

duplicates

# %%
data["Duration_M"] = data.Duration_ms/1000/60

data.Duration_M
