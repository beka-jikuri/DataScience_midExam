# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_parquet('midterm.parquet', engine='pyarrow')
data
# Out:
#                    Artist                                        Spotify_URL  \
# 0                Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1             Beach House  https://open.spotify.com/artist/56ZTgzPBDge0Ov...
# 2                Al Green  https://open.spotify.com/artist/3dkbV4qihUeMsq...
# 3                Al Green  https://open.spotify.com/artist/3dkbV4qihUeMsq...
# 4             Beach House  https://open.spotify.com/artist/56ZTgzPBDge0Ov...
# ...                   ...                                                ...
# 20713   Michael Giacchino  https://open.spotify.com/artist/4kLvhMAuCloLxo...
# 20714                 ATB  https://open.spotify.com/artist/7jZM5w05mGhw6w...
# 20715            Blueface  https://open.spotify.com/artist/3Fl1V19tmjt57o...
# 20716  Tribo da Periferia  https://open.spotify.com/artist/1xxS2WrLlgl9QN...
# 20717            Hardwell  https://open.spotify.com/artist/6BrvowZBreEkXz...
#
#                                         Track  \
# 0                              Feel Good Inc.
# 1                                 Silver Soul
# 2                  I'm Still in Love with You
# 3                          Love and Happiness
# 4                                        Myth
# ...                                       ...
# 20713                            Stuff We Did
# 20714                         Your Love (9PM)
# 20715                                  TikTok
# 20716                             Algo Íntimo
# 20717  Satisfaction - Hardwell & Maddix Remix
#
#                                          Album Album_type  \
# 0                                   Demon Days      Album
# 1                                   Teen Dream      Album
# 2                   I'm Still in Love with You      Album
# 3                   I'm Still in Love with You      Album
# 4                                        Bloom      Album
# ...                                        ...        ...
# 20713  Up (Original Motion Picture Soundtrack)     single
# 20714                          Your Love (9PM)     single
# 20715                                   TikTok     single
# 20716                              Algo Íntimo     single
# 20717   Satisfaction (Hardwell & Maddix Remix)     single
#
#                                         Uri Danceability   Energy   Key  \
# 0      spotify:track:0d28khcov6AiegSCpG5TuT        0.818  0.70500   6.0
# 1      spotify:track:2LZ2CNbcbJrwh53pitRgom        0.356  0.67000   2.0
# 2      spotify:track:2GEDd9qtGXU7IvGgqTF6Uj        0.712  0.39300   0.0
# 3      spotify:track:6SMHgPgNkhe9lneNTbgtel        0.823  0.45700   6.0
# 4      spotify:track:2NfxtzCIrpCmJX5Z2KMdD5        0.445  0.70800   3.0
# ...                                     ...          ...      ...   ...
# 20713  spotify:track:19blFYzqmPj7FtW7W4DFEl        0.256  0.00484   7.0
# 20714  spotify:track:5YaskwnGDZFDRipaqzbwQx        0.669  0.78400   7.0
# 20715  spotify:track:5fMAZiE6Kdqo3fWIOXMtH6        0.752  0.56100   3.0
# 20716  spotify:track:7e0DPzHixf5MyclQRCUkJa        0.662  0.51700   3.0
# 20717  spotify:track:0l6fM0B3KDdGRj7R8vo4hK        0.714  0.89600  11.0
#
#        Loudness  ...                                  Youtube_URL  \
# 0        -6.679  ...  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1        -5.825  ...  https://www.youtube.com/watch?v=njbmwfndFH4
# 2        -9.538  ...  https://www.youtube.com/watch?v=Tg_Guhd6fEY
# 3       -10.961  ...  https://www.youtube.com/watch?v=uPh-31TtEOI
# 4        -6.268  ...  https://www.youtube.com/watch?v=cfBmizHxJec
# ...         ...  ...                                          ...
# 20713   -34.386  ...  https://www.youtube.com/watch?v=16N4OjhjZAE
# 20714    -5.603  ...  https://www.youtube.com/watch?v=9hbu9toStfc
# 20715    -8.754  ...  https://www.youtube.com/watch?v=whsLEiYlcOI
# 20716    -9.079  ...  https://www.youtube.com/watch?v=0jO4y5s3H_g
# 20717    -5.856  ...  https://www.youtube.com/watch?v=t4QkVN324ms
#
#                                            Youtube_Title  \
# 0             Gorillaz - Feel Good Inc. (Official Video)
# 1             Beach House - Silver Soul [OFFICIAL VIDEO]
# 2      Al Green - I'm Still in Love with You (Officia...
# 3      AL Green - Love and Happiness (RE-MASTERED) HD...
# 4                                     Beach House - Myth
# ...                                                  ...
# 20713                                       Stuff We Did
# 20714  ATB, Topic, A7S - Your Love (9PM) (Official Mu...
# 20715           Blueface - TikTok (Official Music Video)
# 20716  Tribo da Periferia - Algo Íntimo (Official Mus...
# 20717  David Guetta vs Benny Benassi  - Satisfaction ...
#
#                  Youtube_Channel  Youtube_Views  Youtube_Likes  \
# 0                       Gorillaz    693555221.0      6220896.0
# 1                        Sub Pop      1837847.0        30695.0
# 2                       Al Green      1604715.0        21048.0
# 3                  VDJ MikeyMike       363208.0         3821.0
# 4               Cosmic Radiation      2439327.0        76693.0
# ...                          ...            ...            ...
# 20713  Michael Giacchino - Topic      4275822.0        91547.0
# 20714                    ATBVEVO     27148915.0       306702.0
# 20715               BluefaceVEVO      6048777.0       188325.0
# 20716         Tribo da Periferia      7842647.0       174912.0
# 20717                   Hardwell       157752.0        10205.0
#
#        Youtube_number_of_Comments  \
# 0                        169907.0
# 1                          1466.0
# 2                           366.0
# 3                           145.0
# 4                           905.0
# ...                           ...
# 20713                      2155.0
# 20714                      4255.0
# 20715                      4508.0
# 20716                      5175.0
# 20717                       357.0
#
#                                      Youtube_Description  \
# 0      Official HD Video for Gorillaz' fantastic trac...
# 1      Subscribe To Sub Pop's YouTube Channel http://...
# 2      Official audio for "I'm Still in Love with You...
# 3      Had to be done.  Couldn't find anything out th...
# 4      The exact video that was present on "I'm cybor...
# ...                                                  ...
# 20713  Provided to YouTube by Universal Music Group\n...
# 20714  ATB, Topic, A7S - 'Your Love (9PM)' out now!\n...
# 20715  Blueface “TikTok” OUT NOW!\nhttps://lnk.to/BFT...
# 20716  Ouça em todas as plataformas digitas: https://...
# 20717  For more info:\r\nhttp://www.djhardwell.com\r\...
#
#       Is_Licensed_on_Youtube Is_official_video Spotify_stream_num
# 0                       True              True       1.040235e+09
# 1                       True              True       8.343322e+07
# 2                       True              True       2.748388e+07
# 3                      False             False       8.005354e+07
# 4                      False             False       1.141535e+08
# ...                      ...               ...                ...
# 20713                   True              True       3.922862e+07
# 20714                   True              True       5.613685e+08
# 20715                   True              True       1.411268e+07
# 20716                   True              True       3.334337e+06
# 20717                  False              True                NaN
#
# [20718 rows x 27 columns]

# %% [markdown]
# პირველ რიგში წამოვიღებთ დატას ქოლამნებს რომ გავიგოთ რასთან მოგვიწევს მუშაობა, აგრეთვე გავიგებთ რა შეიფი აქვს ჩვენს ფაილს.

# %%
data.shape
data.columns
# Out:
# Index(['Artist', 'Spotify_URL', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Youtube_URL', 'Youtube_Title', 'Youtube_Channel',
#        'Youtube_Views', 'Youtube_Likes', 'Youtube_number_of_Comments',
#        'Youtube_Description', 'Is_Licensed_on_Youtube', 'Is_official_video',
#        'Spotify_stream_num'],
#       dtype='object')

# %% [markdown]
# ვარკვევთ არის თუ არა ნალები მონაცემებში და დადებითი პასუხის შემთხვევაში სად და რამდენი

# %%
data.isnull().sum()
# Out:
# Artist                          0
# Spotify_URL                     0
# Track                           0
# Album                           0
# Album_type                      0
# Uri                             0
# Danceability                    0
# Energy                          2
# Key                             2
# Loudness                        2
# Speechiness                     2
# Acousticness                    2
# Instrumentalness                2
# Liveness                        2
# Valence                         2
# Tempo                           2
# Duration_ms                     2
# Youtube_URL                   470
# Youtube_Title                   0
# Youtube_Channel               470
# Youtube_Views                 470
# Youtube_Likes                   0
# Youtube_number_of_Comments    569
# Youtube_Description           876
# Is_Licensed_on_Youtube        470
# Is_official_video             470
# Spotify_stream_num            576
# dtype: int64

# %%
data["dup_bool"] = data.duplicated("Uri")
duplicates = data.loc[data["dup_bool" ]== True]
duplicates.sort_values(by = 'Uri',ascending=False)
# Out:
#                 Artist                                        Spotify_URL  \
# 13501       Young Thug  https://open.spotify.com/artist/50co4Is1HCEo8b...
# 18342      Wiz Khalifa  https://open.spotify.com/artist/137W8MRPWKqSmr...
# 17764  Stephen Sanchez  https://open.spotify.com/artist/5XKFrudbV4IiuE...
# 15325   Sorriso Maroto  https://open.spotify.com/artist/1fUSLFr4WUBx7j...
# 6161         A$AP Ferg  https://open.spotify.com/artist/5dHt1vcEm9qb8f...
# ...                ...                                                ...
# 15675      Miley Cyrus  https://open.spotify.com/artist/5YGY8feqx7naU7...
# 5965        Silk Sonic  https://open.spotify.com/artist/6PvvGcCY2XtUcS...
# 10042       Bruno Mars  https://open.spotify.com/artist/0du5cEVh5yTK9Q...
# 15300   Sorriso Maroto  https://open.spotify.com/artist/1fUSLFr4WUBx7j...
# 12513       Kane Brown  https://open.spotify.com/artist/3oSJ7TBVCWMDMi...
#
#                                                    Track  \
# 13501        Livin It Up (with Post Malone & A$AP Rocky)
# 18342  Shell Shocked (feat. Kill the Noise & Madsonik...
# 17764                            Missing You (with Ashe)
# 15325                                   Mensagem Apagada
# 6161   Work REMIX (feat. A$AP Rocky, French Montana, ...
# ...                                                  ...
# 15675    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 5965                                 Leave The Door Open
# 10042                                Leave The Door Open
# 15300                                 50 Vezes - Ao Vivo
# 12513                                     Famous Friends
#
#                                                    Album Album_type  \
# 13501                                               Punk      album
# 18342  Shell Shocked (feat. Kill the Noise & Madsonik...     single
# 17764                                        Missing You     single
# 15325                                             Juntos      album
# 6161                                           Trap Lord      Album
# ...                                                  ...        ...
# 15675                                Late Night Feelings      album
# 5965                          An Evening With Silk Sonic      Album
# 10042                         An Evening With Silk Sonic      album
# 15300                         Ao Cubo, Ao Vivo, Em Cores      album
# 12513                                     Famous Friends      album
#
#                                         Uri Danceability  Energy  Key  \
# 13501  spotify:track:7zjEyeBsaw9gV0jofJLfOM        0.767   0.313  7.0
# 18342  spotify:track:7zBQRGpYImAdIZc97FNj3V        0.596   0.815  6.0
# 17764  spotify:track:7xtsuU7WlDNmTzUQ32oQ7r        0.639   0.340  0.0
# 15325  spotify:track:7xoW9ae2eFXgzw2JFkttmq        0.631   0.596  0.0
# 6161   spotify:track:7xVLFuuYdAvcTfcP3IG3dS        0.841   0.733  1.0
# ...                                     ...          ...     ...  ...
# 15675  spotify:track:02dRkCEc8Q5ch4TTcnLxOn        0.601   0.794  7.0
# 5965   spotify:track:02VBYrHfVwfEWXk5DXyf0T        0.586   0.616  5.0
# 10042  spotify:track:02VBYrHfVwfEWXk5DXyf0T        0.586   0.616  5.0
# 15300  spotify:track:01wavOnjFBNgdMWBFYIAP4        0.561   0.650  7.0
# 12513  spotify:track:00KyYtT6NaXwbPecina5Pj        0.535   0.859  6.0
#
#        Loudness  ...                                      Youtube_Title  \
# 13501   -12.059  ...  Young Thug - Livin It Up (with Post Malone & A...
# 18342    -5.668  ...  Juicy J, Wiz Khalifa, Ty Dolla $ign - Shell Sh...
# 17764   -12.185  ...  Stephen Sanchez & Ashe - Missing You (Official...
# 15325    -7.708  ...  Dilsinho, Sorriso Maroto - Mensagem Apagada (C...
# 6161     -5.077  ...  A$AP Ferg - Work REMIX ft. A$AP ROCKY, French ...
# ...         ...  ...                                                ...
# 15675    -5.844  ...  Mark Ronson - Nothing Breaks Like a Heart (Off...
# 5965     -7.964  ...  Bruno Mars, Anderson .Paak, Silk Sonic - Leave...
# 10042    -7.964  ...  Bruno Mars, Anderson .Paak, Silk Sonic - Leave...
# 15300    -6.430  ...  Sorriso Maroto, Dilsinho - 50 Vezes (Ao Vivo) ...
# 12513    -2.922  ...  Chris Young, Kane Brown - Famous Friends (Offi...
#
#           Youtube_Channel  Youtube_Views  Youtube_Likes  \
# 13501          Young Thug      3489224.0        77238.0
# 18342    Atlantic Records    192128213.0      1460377.0
# 17764  StephenSanchezVEVO       344264.0        13875.0
# 15325        DilsinhoVEVO     31751294.0       181715.0
# 6161         asapfergVEVO      1010850.0        14035.0
# ...                   ...            ...            ...
# 15675      MarkRonsonVEVO    322683243.0      3798746.0
# 5965           Bruno Mars    637673269.0      6925306.0
# 10042          Bruno Mars    637665698.0      6925257.0
# 15300      Sorriso Maroto    134730976.0       567096.0
# 12513      ChrisYoungVEVO     19838446.0       111657.0
#
#        Youtube_number_of_Comments  \
# 13501                      1868.0
# 18342                     37675.0
# 17764                       387.0
# 15325                      2507.0
# 6161                        432.0
# ...                           ...
# 15675                     94493.0
# 5965                     193397.0
# 10042                    193396.0
# 15300                      8724.0
# 12513                      6466.0
#
#                                      Youtube_Description  \
# 13501  The official audio for Young Thug's "Livin It ...
# 18342  The official video of "Shell Shocked (feat.. K...
# 17764  Music video by Stephen Sanchez, Ashe performin...
# 15325  Vídeo Oficial de "Mensagem Apagada" de Dilsinh...
# 6161   http://smarturl.it/workremix       Music video...
# ...                                                  ...
# 15675  Mark Ronson feat. Miley Cyrus - Nothing Breaks...
# 5965   The official music video for Bruno Mars, Ander...
# 10042  The official music video for Bruno Mars, Ander...
# 15300  Este é o clipe oficial da música "50 Vezes", f...
# 12513  Listen to “Famous Friends” by Chris Young & Ka...
#
#        Is_Licensed_on_Youtube Is_official_video Spotify_stream_num dup_bool
# 13501                    True              True       1.075726e+08     True
# 18342                    True              True       1.543113e+08     True
# 17764                    True              True       3.710853e+06     True
# 15325                    True              True       2.903302e+07     True
# 6161                     True              True       3.386397e+08     True
# ...                       ...               ...                ...      ...
# 15675                    True              True       7.132119e+08     True
# 5965                     True              True       1.006100e+09     True
# 10042                    True              True       1.006100e+09     True
# 15300                   False              True       9.172190e+07     True
# 12513                    True              True       1.259896e+08     True
#
# [1856 rows x 28 columns]
